# %% [markdown]
# # Script to download pitch-level play by play data

# %%
# #### Uncomment to download pitch-level data

# from pybaseball import statcast
# import pandas as pd
# import time

# # years = [2019, 2020, 2021]
# # years = [2022, 2023, 2024]
# # years = [2024]
# # years = [2025]

# for y in years:
#     print(f"Downloading Statcast data for {y}...")

#     # Statcast date range (regular season)
#     start = f"{y}-03-01"
#     end   = f"{y}-11-30"

#     # Download the year
#     df = statcast(start_dt=start, end_dt=end)
#     df["year"] = y

#     # Save to a separate CSV
#     filename = f"statcast_pitch_by_pitch_{y}.csv"
#     df.to_csv(filename, index=False)

#     print(f"Saved {filename} ({len(df)} rows)")

#     # polite pause to avoid server overload
#     time.sleep(3)
